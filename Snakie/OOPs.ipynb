# %%
class Hello():
    print("Hello")

# Hello()
# Out:
# Hello

# %%
class Hello:
    print("Hello")

# Hello()
# Out:
# Hello

# %%
class Hello:
    def __init__(self):
        print("Hello")
Hello()
# Out:
# Hello

# %%
class Tesla:
    def __init__(self,car,price):
        self.car=car
        self.price=price
        print(f"The price {price} for car {car}")
    
Tesla("Hyundai",23)
# Out:
# The price 23 for car Hyundai

# %%
# Non-Parameterized Constructor
class Drone:
    def __init__(self):
        self.status="Grounded"

# %%
# Basic Inheritance Example

# Parent Class (Superclass)
class Electronics:
    def __init__(self):
        self.power_status="OFF"
    
    def turn_on(self):
        self.power_status="ON"
        print("Device is now powered ON\n")

# Child Class (Subclass)
class Drone(Electronics):
    def fly(self):
        if self.power_status=="ON":
            print("The drone is now flying")
        else:
            print("Cannot fly:Power is OFF")

# Usage
my_drone=Drone()
my_drone.turn_on()
my_drone.fly()
# Out:
# Device is now powered ON
#
# The drone is now flying
